# %%
# !pip install beautifulsoup4

# %%
# !pip install requests

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.flipkart.com/sony-138-8-cm-55-inch-ultra-hd-4k-led-smart-google-tv/p/itm787d15734ffcc?pid=TVSGHHWM9DGAWASR&lid=LSTTVSGHHWM9DGAWASRWZGXMW&marketplace=FLIPKART&fm=neo%2Fmerchandising&iid=M_fcb48425-4358-4eeb-8e98-e438e5a4fbcb_18_POG5MAHPSCV9_MC.TVSGHHWM9DGAWASR&ppt=clp&ppn=mobile-phones-bsd-june-aj83n-nou87-store&ssid=picsai3x3k0000001686570183589&otracker=clp_pmu_v2_55%2BInch%2BTVs_4_18.productCard.PMU_V2_SONY%2B138.8%2Bcm%2B%252855%2Binch%2529%2BUltra%2BHD%2B%25284K%2529%2BLED%2BSmart%2BGoogle%2BTV_television-store_TVSGHHWM9DGAWASR_neo%2Fmerchandising_3&otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_55%2BInch%2BTVs_LIST_productCard_cc_4_NA_view-all&cid=TVSGHHWM9DGAWASR"
response=requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
soup=BeautifulSoup(response.text,"html.parser")
title1=soup.find("div",{"class":"_1YokD2 _2GoDe3"})
title1
# Out:
# <div class="_1YokD2 _2GoDe3" style="background-color:#FFFFFF;padding:16px 16px 16px 16px"><div class="_1YokD2 _3Mn1Gg col-5-12 _78xt5Y"><div class="_1AtVbE col-12-12"><div class="_1iyjIJ"><div class="_3li7GG"><div class="_35DpL-"><div class="_2FHWw4"><div class="_2mLllQ" style="height:1280px"><ul class="_3GnUWp" style="-webkit-transform:translateY(-0px);-moz-transform:translateY(-0px);-o-transform:translateY(-0px);-ms-transform:translateY(-0px);transform:translateY(-0px)"><li class="_20Gt85 _1Y_A6W" style="height:64px"><div class="_1AuMiq P9aMAP"><div class="_2E1FGS"><img class="q6DClP" src="https://rukminim1.flixcart.com/image/128/128/xif0q/television/d/k/e/-original-imagm2e6ztgrawkg.jpeg?q=70"/></div></div></li><li class="_20Gt85 _1Y_A6W" style="height:64px"><div class="_1AuMiq"><div class="_2E1FGS"><img class="q6DClP" src="https://rukminim1.flixcart.com/image/128/128/xif0q/television/d/k/e/-original-imagm2e6ztgrawkg.jpeg?q=70"/></div><div class="_2usHgU"></div><div class="_3g-Cpg"
# ...

# %%
df=pd.read_html(str(title1))
df
# Out:
# [                             0  \
#  0                   In The Box
#  1                   Model Name
#  2                 Display Size
#  3                  Screen Type
#  4   HD Technology & Resolution
#  5                     Smart Tv
#  6                         HDMI
#  7                          USB
#  8               Built In Wi-Fi
#  9                  Launch Year
#  10         Wall Mount Included
#
#                                                      1
#  0   1 Unit TV, Warranty Card, AC Power Cord, Remot...
#  1                                           KD-55X74K
#  2                                  138.8 cm (55 inch)
#  3                                                 LED
#  4                          Ultra HD (4K), 3840 x 2160
#  5                                                 Yes
#  6                                                   3
#  7                                                   2
#  8                                                 Yes
# ...

# %%
df=pd.DataFrame(df[0])
df
# Out:
#                              0  \
# 0                   In The Box
# 1                   Model Name
# 2                 Display Size
# 3                  Screen Type
# 4   HD Technology & Resolution
# 5                     Smart Tv
# 6                         HDMI
# 7                          USB
# 8               Built In Wi-Fi
# 9                  Launch Year
# 10         Wall Mount Included
#
#                                                     1
# 0   1 Unit TV, Warranty Card, AC Power Cord, Remot...
# 1                                           KD-55X74K
# 2                                  138.8 cm (55 inch)
# 3                                                 LED
# 4                          Ultra HD (4K), 3840 x 2160
# 5                                                 Yes
# 6                                                   3
# 7                                                   2
# 8                                                 Yes
# ...

# %%
df.to_csv("Tv_Scrape.csv",index=False)
